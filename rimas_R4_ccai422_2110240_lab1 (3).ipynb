# %% [markdown]
# ### Rimas Alshehri-Lab1

# %% [markdown]
# ### Task 1

# %% [markdown]
# #### Introducing the pandas DataFrame

# %%
import pandas as pd

# %%
data = {
     'name': ['Xavier', 'Ann', 'Jana', 'Yi', 'Robin', 'Amal', 'Nori'],
     'city': ['Mexico City', 'Toronto', 'Prague', 'Shanghai',
              'Manchester', 'Cairo', 'Osaka'],
     'age': [41, 28, 33, 34, 38, 31, 37],
     'py-score': [88.0, 79.0, 81.0, 80.0, 68.0, 61.0, 84.0]
}

row_labels = [101, 102, 103, 104, 105, 106, 107]

# %%
df = pd.DataFrame(data=data, index=row_labels)

# %%
df
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 105   Robin   Manchester   38      68.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %%
df.head(n=2)
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0

# %%
df.tail(n=2)
# Out:
#      name   city  age  py-score
# 106  Amal  Cairo   31      61.0
# 107  Nori  Osaka   37      84.0

# %% [markdown]
# #### 3-	Add to the data frame a new record with your name and random values for other columns

# %%
df.loc[108] = ['Rimas', 'Jeddah', 21, np.random.uniform(60, 100)]

# %%
df
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41  88.00000
# 102     Ann      Toronto   28  79.00000
# 103    Jana       Prague   33  81.00000
# 104      Yi     Shanghai   34  80.00000
# 105   Robin   Manchester   38  68.00000
# 106    Amal        Cairo   31  61.00000
# 107    Nori        Osaka   37  84.00000
# 108   Rimas       Jeddah   21  74.43776

# %%
#for checking only
df.tail(n=2)
# Out:
#       name    city  age  py-score
# 107   Nori   Osaka   37  84.00000
# 108  Rimas  Jeddah   21  74.43776

# %%
cities = df['city']
cities
# Out:
# 101    Mexico City
# 102        Toronto
# 103         Prague
# 104       Shanghai
# 105     Manchester
# 106          Cairo
# 107          Osaka
# 108         Jeddah
# Name: city, dtype: object

# %%
df.city
# Out:
# 101    Mexico City
# 102        Toronto
# 103         Prague
# 104       Shanghai
# 105     Manchester
# 106          Cairo
# 107          Osaka
# 108         Jeddah
# Name: city, dtype: object

# %%
cities[102]
# Out:
# 'Toronto'

# %%
df.loc[103]
# Out:
# name          Jana
# city        Prague
# age             33
# py-score      81.0
# Name: 103, dtype: object

# %% [markdown]
# #### Creating a pandas DataFrame

# %%
import numpy as np
import pandas as pd

# %%
d = {'x': [1, 2, 3], 'y': np.array([2, 4, 8]), 'z': 100}

pd.DataFrame(d)
# Out:
#    x  y    z
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %%
pd.DataFrame(d, index=[100, 200, 300], columns=['z', 'y', 'x'])
# Out:
#        z  y  x
# 100  100  2  1
# 200  100  4  2
# 300  100  8  3

# %% [markdown]
# #### Creating a pandas DataFrame With Lists

# %%
l = [{'x': 1, 'y': 2, 'z': 100},
     {'x': 2, 'y': 4, 'z': 100},
     {'x': 3, 'y': 8, 'z': 100}]

pd.DataFrame(l)
# Out:
#    x  y    z
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %%
l = [[1, 2, 100],
      [2, 4, 100],
      [3, 8, 100]]

pd.DataFrame(l, columns=['x', 'y', 'z'])
# Out:
#    x  y    z
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %% [markdown]
# #### Creating a pandas DataFrame With NumPy Arrays

# %%
arr = np.array([[1, 2, 100],
                 [2, 4, 100],
                 [3, 8, 100]])

df_ = pd.DataFrame(arr, columns=['x', 'y', 'z'])
df_
# Out:
#    x  y    z
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %%
arr[0, 0] = 1000

df_
# Out:
#       x  y    z
# 0  1000  2  100
# 1     2  4  100
# 2     3  8  100

# %% [markdown]
# #### Creating a pandas DataFrame From Files

# %%
df.to_csv('data.csv')

# %%
pd.read_csv('data.csv', index_col=0)
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41  88.00000
# 102     Ann      Toronto   28  79.00000
# 103    Jana       Prague   33  81.00000
# 104      Yi     Shanghai   34  80.00000
# 105   Robin   Manchester   38  68.00000
# 106    Amal        Cairo   31  61.00000
# 107    Nori        Osaka   37  84.00000
# 108   Rimas       Jeddah   21  74.43776

# %% [markdown]
# #### Retrieving Labels and Data

# %%
df.index
# Out:
# Index([101, 102, 103, 104, 105, 106, 107, 108], dtype='int64')

# %%
df.columns
# Out:
# Index(['name', 'city', 'age', 'py-score'], dtype='object')

# %%
df.columns[1]
# Out:
# 'city'

# %%
# Ensure the new index has the same length as the existing DataFrame.
df.index = np.arange(10, 18)

# %%
df.index
# Out:
# Index([10, 11, 12, 13, 14, 15, 16, 17], dtype='int64')

# %%
df
# Out:
#       name         city  age  py-score
# 10  Xavier  Mexico City   41  88.00000
# 11     Ann      Toronto   28  79.00000
# 12    Jana       Prague   33  81.00000
# 13      Yi     Shanghai   34  80.00000
# 14   Robin   Manchester   38  68.00000
# 15    Amal        Cairo   31  61.00000
# 16    Nori        Osaka   37  84.00000
# 17   Rimas       Jeddah   21  74.43776

# %% [markdown]
# #### Data as NumPy Arrays

# %%
df.to_numpy()
# Out:
# array([['Xavier', 'Mexico City', 41, 88.0],
#        ['Ann', 'Toronto', 28, 79.0],
#        ['Jana', 'Prague', 33, 81.0],
#        ['Yi', 'Shanghai', 34, 80.0],
#        ['Robin', 'Manchester', 38, 68.0],
#        ['Amal', 'Cairo', 31, 61.0],
#        ['Nori', 'Osaka', 37, 84.0],
#        ['Rimas', 'Jeddah', 21, 74.43776002896705]], dtype=object)

# %% [markdown]
# #### Data Types

# %%
df.dtypes
# Out:
# name         object
# city         object
# age           int64
# py-score    float64
# dtype: object

# %%
df_ = df.astype(dtype={'age': np.int32, 'py-score': np.float32})
df_.dtypes
# Out:
# name         object
# city         object
# age           int32
# py-score    float32
# dtype: object

# %% [markdown]
# #### pandas DataFrame Size

# %%
df_.ndim
# Out:
# 2

# %%
df_.shape
# Out:
# (8, 4)

# %%
df_.size
# Out:
# 32

# %%
df_.memory_usage()
# Out:
# Index       64
# name        64
# city        64
# age         32
# py-score    32
# dtype: int64

# %% [markdown]
# #### Accessing and Modifying Data

# %%
df['name']
# Out:
# 10    Xavier
# 11       Ann
# 12      Jana
# 13        Yi
# 14     Robin
# 15      Amal
# 16      Nori
# 17     Rimas
# Name: name, dtype: object

# %%
df.loc[10]
# Out:
# name             Xavier
# city        Mexico City
# age                  41
# py-score           88.0
# Name: 10, dtype: object

# %% [markdown]
# #### Getting Data With Accessors

# %%
df.loc[10]
# Out:
# name             Xavier
# city        Mexico City
# age                  41
# py-score           88.0
# Name: 10, dtype: object

# %%
df.iloc[0]
# Out:
# name             Xavier
# city        Mexico City
# age                  41
# py-score           88.0
# Name: 10, dtype: object

# %%
df.loc[:, 'city']
# Out:
# 10    Mexico City
# 11        Toronto
# 12         Prague
# 13       Shanghai
# 14     Manchester
# 15          Cairo
# 16          Osaka
# 17         Jeddah
# Name: city, dtype: object

# %%
df.iloc[:, 1]
# Out:
# 10    Mexico City
# 11        Toronto
# 12         Prague
# 13       Shanghai
# 14     Manchester
# 15          Cairo
# 16          Osaka
# 17         Jeddah
# Name: city, dtype: object

# %%
df.loc[11:15, ['name', 'city']]
# Out:
#      name        city
# 11    Ann     Toronto
# 12   Jana      Prague
# 13     Yi    Shanghai
# 14  Robin  Manchester
# 15   Amal       Cairo

# %%
df.iloc[1:6, [0, 1]]
# Out:
#      name        city
# 11    Ann     Toronto
# 12   Jana      Prague
# 13     Yi    Shanghai
# 14  Robin  Manchester
# 15   Amal       Cairo

# %%
df.iloc[1:6:2, 0]
# Out:
# 11     Ann
# 13      Yi
# 15    Amal
# Name: name, dtype: object

# %%
df.iloc[slice(1, 6, 2), 0]
# Out:
# 11     Ann
# 13      Yi
# 15    Amal
# Name: name, dtype: object

# %%
df.iloc[np.s_[1:6:2], 0]
# Out:
# 11     Ann
# 13      Yi
# 15    Amal
# Name: name, dtype: object

# %%
df.iloc[pd.IndexSlice[1:6:2], 0]
# Out:
# 11     Ann
# 13      Yi
# 15    Amal
# Name: name, dtype: object

# %%
df.at[12, 'name']
# Out:
# 'Jana'

# %%
df.iat[2, 0]
# Out:
# 'Jana'

# %% [markdown]
# #### Setting Data With Accessors

# %%
df.loc[:, 'py-score']
# Out:
# 10    88.00000
# 11    79.00000
# 12    81.00000
# 13    80.00000
# 14    68.00000
# 15    61.00000
# 16    84.00000
# 17    74.43776
# Name: py-score, dtype: float64

# %%
df.loc[:13, 'py-score'] = [40, 50, 60, 70]
df.loc[14:, 'py-score'] = 0

# %%
df['py-score']
# Out:
# 10    40.0
# 11    50.0
# 12    60.0
# 13    70.0
# 14     0.0
# 15     0.0
# 16     0.0
# 17     0.0
# Name: py-score, dtype: float64

# %%
df.iloc[:, -1] = np.array([88.0, 79.0, 81.0, 80.0, 68.0, 61.0, 84.0,88.0 ])

# %% [markdown]
# #### Inserting and Deleting Data

# %%
john = pd.Series(data=['John', 'Boston', 34, 79],
                 index=df.columns, name=17)

# %%
john
# Out:
# name          John
# city        Boston
# age             34
# py-score        79
# Name: 17, dtype: object

# %%
john.name
# Out:
# 17

# %%
df = pd.concat([df, pd.DataFrame([john])], ignore_index=True)

# %%
df
# Out:
#      name         city  age  py-score
# 0  Xavier  Mexico City   41      88.0
# 1     Ann      Toronto   28      79.0
# 2    Jana       Prague   33      81.0
# 3      Yi     Shanghai   34      80.0
# 4   Robin   Manchester   38      68.0
# 5    Amal        Cairo   31      61.0
# 6    Nori        Osaka   37      84.0
# 7   Rimas       Jeddah   21      88.0
# 8    John       Boston   34      79.0

# %%
df = df.drop(index=df.index[-1])

# %%
df
# Out:
#      name         city  age  py-score
# 0  Xavier  Mexico City   41      88.0
# 1     Ann      Toronto   28      79.0
# 2    Jana       Prague   33      81.0
# 3      Yi     Shanghai   34      80.0
# 4   Robin   Manchester   38      68.0
# 5    Amal        Cairo   31      61.0
# 6    Nori        Osaka   37      84.0
# 7   Rimas       Jeddah   21      88.0

# %% [markdown]
# #### Inserting and Deleting Columns

# %%
df['js-score'] = np.array([71.0, 95.0, 88.0, 79.0, 91.0, 91.0, 80.0, 80.0 ])
df
# Out:
#      name         city  age  py-score  js-score
# 0  Xavier  Mexico City   41      88.0      71.0
# 1     Ann      Toronto   28      79.0      95.0
# 2    Jana       Prague   33      81.0      88.0
# 3      Yi     Shanghai   34      80.0      79.0
# 4   Robin   Manchester   38      68.0      91.0
# 5    Amal        Cairo   31      61.0      91.0
# 6    Nori        Osaka   37      84.0      80.0
# 7   Rimas       Jeddah   21      88.0      80.0

# %%
df['total-score'] = 0.0
df
# Out:
#      name         city  age  py-score  js-score  total-score
# 0  Xavier  Mexico City   41      88.0      71.0          0.0
# 1     Ann      Toronto   28      79.0      95.0          0.0
# 2    Jana       Prague   33      81.0      88.0          0.0
# 3      Yi     Shanghai   34      80.0      79.0          0.0
# 4   Robin   Manchester   38      68.0      91.0          0.0
# 5    Amal        Cairo   31      61.0      91.0          0.0
# 6    Nori        Osaka   37      84.0      80.0          0.0
# 7   Rimas       Jeddah   21      88.0      80.0          0.0

# %%
df.insert(loc=4, column='django-score',
           value=np.array([86.0, 81.0, 78.0, 88.0, 74.0, 70.0, 81.0, 81.0]))
df
# Out:
#      name         city  age  py-score  django-score  js-score  total-score
# 0  Xavier  Mexico City   41      88.0          86.0      71.0          0.0
# 1     Ann      Toronto   28      79.0          81.0      95.0          0.0
# 2    Jana       Prague   33      81.0          78.0      88.0          0.0
# 3      Yi     Shanghai   34      80.0          88.0      79.0          0.0
# 4   Robin   Manchester   38      68.0          74.0      91.0          0.0
# 5    Amal        Cairo   31      61.0          70.0      91.0          0.0
# 6    Nori        Osaka   37      84.0          81.0      80.0          0.0
# 7   Rimas       Jeddah   21      88.0          81.0      80.0          0.0

# %%
del df['total-score']
df
# Out:
#      name         city  age  py-score  django-score  js-score
# 0  Xavier  Mexico City   41      88.0          86.0      71.0
# 1     Ann      Toronto   28      79.0          81.0      95.0
# 2    Jana       Prague   33      81.0          78.0      88.0
# 3      Yi     Shanghai   34      80.0          88.0      79.0
# 4   Robin   Manchester   38      68.0          74.0      91.0
# 5    Amal        Cairo   31      61.0          70.0      91.0
# 6    Nori        Osaka   37      84.0          81.0      80.0
# 7   Rimas       Jeddah   21      88.0          81.0      80.0

# %%
df = df.drop(labels='age', axis=1)
df
# Out:
#      name         city  py-score  django-score  js-score
# 0  Xavier  Mexico City      88.0          86.0      71.0
# 1     Ann      Toronto      79.0          81.0      95.0
# 2    Jana       Prague      81.0          78.0      88.0
# 3      Yi     Shanghai      80.0          88.0      79.0
# 4   Robin   Manchester      68.0          74.0      91.0
# 5    Amal        Cairo      61.0          70.0      91.0
# 6    Nori        Osaka      84.0          81.0      80.0
# 7   Rimas       Jeddah      88.0          81.0      80.0

# %% [markdown]
# #### Applying Arithmetic Operations

# %%
df['py-score'] + df['js-score']
# Out:
# 0    159.0
# 1    174.0
# 2    169.0
# 3    159.0
# 4    159.0
# 5    152.0
# 6    164.0
# 7    168.0
# dtype: float64

# %%
df['py-score'] / 100
# Out:
# 0    0.88
# 1    0.79
# 2    0.81
# 3    0.80
# 4    0.68
# 5    0.61
# 6    0.84
# 7    0.88
# Name: py-score, dtype: float64

# %%
df['total'] =\
     0.4 * df['py-score'] + 0.3 * df['django-score'] + 0.3 * df['js-score']
df
# Out:
#      name         city  py-score  django-score  js-score  total
# 0  Xavier  Mexico City      88.0          86.0      71.0   82.3
# 1     Ann      Toronto      79.0          81.0      95.0   84.4
# 2    Jana       Prague      81.0          78.0      88.0   82.2
# 3      Yi     Shanghai      80.0          88.0      79.0   82.1
# 4   Robin   Manchester      68.0          74.0      91.0   76.7
# 5    Amal        Cairo      61.0          70.0      91.0   72.7
# 6    Nori        Osaka      84.0          81.0      80.0   81.9
# 7   Rimas       Jeddah      88.0          81.0      80.0   83.5

# %% [markdown]
# #### Applying NumPy and SciPy Functions

# %%
score = df.iloc[:, 2:5]
score
# Out:
#    py-score  django-score  js-score
# 0      88.0          86.0      71.0
# 1      79.0          81.0      95.0
# 2      81.0          78.0      88.0
# 3      80.0          88.0      79.0
# 4      68.0          74.0      91.0
# 5      61.0          70.0      91.0
# 6      84.0          81.0      80.0
# 7      88.0          81.0      80.0

# %%
np.average(score, axis=1,
            weights=[0.4, 0.3, 0.3])
# Out:
# array([82.3, 84.4, 82.2, 82.1, 76.7, 72.7, 81.9, 83.5])

# %%
del df['total']
df
# Out:
#      name         city  py-score  django-score  js-score
# 0  Xavier  Mexico City      88.0          86.0      71.0
# 1     Ann      Toronto      79.0          81.0      95.0
# 2    Jana       Prague      81.0          78.0      88.0
# 3      Yi     Shanghai      80.0          88.0      79.0
# 4   Robin   Manchester      68.0          74.0      91.0
# 5    Amal        Cairo      61.0          70.0      91.0
# 6    Nori        Osaka      84.0          81.0      80.0
# 7   Rimas       Jeddah      88.0          81.0      80.0

# %%
df['total'] = np.average(df.iloc[:, 2:5], axis=1,
                          weights=[0.4, 0.3, 0.3])
df
# Out:
#      name         city  py-score  django-score  js-score  total
# 0  Xavier  Mexico City      88.0          86.0      71.0   82.3
# 1     Ann      Toronto      79.0          81.0      95.0   84.4
# 2    Jana       Prague      81.0          78.0      88.0   82.2
# 3      Yi     Shanghai      80.0          88.0      79.0   82.1
# 4   Robin   Manchester      68.0          74.0      91.0   76.7
# 5    Amal        Cairo      61.0          70.0      91.0   72.7
# 6    Nori        Osaka      84.0          81.0      80.0   81.9
# 7   Rimas       Jeddah      88.0          81.0      80.0   83.5

# %% [markdown]
# #### Sorting a pandas DataFrame

# %%
df.sort_values(by='js-score', ascending=False)
# Out:
#      name         city  py-score  django-score  js-score  total
# 1     Ann      Toronto      79.0          81.0      95.0   84.4
# 4   Robin   Manchester      68.0          74.0      91.0   76.7
# 5    Amal        Cairo      61.0          70.0      91.0   72.7
# 2    Jana       Prague      81.0          78.0      88.0   82.2
# 6    Nori        Osaka      84.0          81.0      80.0   81.9
# 7   Rimas       Jeddah      88.0          81.0      80.0   83.5
# 3      Yi     Shanghai      80.0          88.0      79.0   82.1
# 0  Xavier  Mexico City      88.0          86.0      71.0   82.3

# %%
df.sort_values(by=['total', 'py-score'], ascending=[False, False])
# Out:
#      name         city  py-score  django-score  js-score  total
# 1     Ann      Toronto      79.0          81.0      95.0   84.4
# 7   Rimas       Jeddah      88.0          81.0      80.0   83.5
# 0  Xavier  Mexico City      88.0          86.0      71.0   82.3
# 2    Jana       Prague      81.0          78.0      88.0   82.2
# 3      Yi     Shanghai      80.0          88.0      79.0   82.1
# 6    Nori        Osaka      84.0          81.0      80.0   81.9
# 4   Robin   Manchester      68.0          74.0      91.0   76.7
# 5    Amal        Cairo      61.0          70.0      91.0   72.7

# %% [markdown]
# #### Filtering Data

# %%
filter_ = df['django-score'] >= 80
filter_
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# Name: django-score, dtype: bool

# %%
df[filter_]
# Out:
#      name         city  py-score  django-score  js-score  total
# 0  Xavier  Mexico City      88.0          86.0      71.0   82.3
# 1     Ann      Toronto      79.0          81.0      95.0   84.4
# 3      Yi     Shanghai      80.0          88.0      79.0   82.1
# 6    Nori        Osaka      84.0          81.0      80.0   81.9
# 7   Rimas       Jeddah      88.0          81.0      80.0   83.5

# %%
df[(df['py-score'] >= 80) & (df['js-score'] >= 80)]
# Out:
#     name    city  py-score  django-score  js-score  total
# 2   Jana  Prague      81.0          78.0      88.0   82.2
# 6   Nori   Osaka      84.0          81.0      80.0   81.9
# 7  Rimas  Jeddah      88.0          81.0      80.0   83.5

# %%
df['django-score'].where(cond=df['django-score'] >= 80, other=0.0)
# Out:
# 0    86.0
# 1    81.0
# 2     0.0
# 3    88.0
# 4     0.0
# 5     0.0
# 6    81.0
# 7    81.0
# Name: django-score, dtype: float64

# %% [markdown]
# #### Determining Data Statistics

# %%
df.describe()
# Out:
#         py-score  django-score   js-score      total
# count   8.000000      8.000000   8.000000   8.000000
# mean   78.625000     79.875000  84.375000  80.725000
# std     9.530965      5.890367   8.105333   3.959347
# min    61.000000     70.000000  71.000000  72.700000
# 25%    76.250000     77.000000  79.750000  80.600000
# 50%    80.500000     81.000000  84.000000  82.150000
# 75%    85.000000     82.250000  91.000000  82.600000
# max    88.000000     88.000000  95.000000  84.400000

# %%
df.select_dtypes(include=np.number).mean()
# Out:
# py-score        78.625
# django-score    79.875
# js-score        84.375
# total           80.725
# dtype: float64

# %%
df['py-score'].mean()
# Out:
# 78.625

# %%
df.select_dtypes(include=np.number).std()
# Out:
# py-score        9.530965
# django-score    5.890367
# js-score        8.105333
# total           3.959347
# dtype: float64

# %%
df['py-score'].std()
# Out:
# 9.530964574180606

# %% [markdown]
# #### Handling Missing Data

# %%
df_ = pd.DataFrame({'x': [1, 2, np.nan, 4]})
df_
# Out:
#      x
# 0  1.0
# 1  2.0
# 2  NaN
# 3  4.0

# %% [markdown]
# #### Calculating With Missing Data

# %%
df_.mean()
# Out:
# x    2.333333
# dtype: float64

# %%
df_.mean(skipna=False)
# Out:
# x   NaN
# dtype: float64

# %% [markdown]
# #### Filling Missing Data

# %%
df_.fillna(value=0)
# Out:
#      x
# 0  1.0
# 1  2.0
# 2  0.0
# 3  4.0

# %%
df_.fillna(method='ffill')
# Out:
# <ipython-input-146-16aa17916acd>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_.fillna(method='ffill')
#      x
# 0  1.0
# 1  2.0
# 2  2.0
# 3  4.0

# %%
df_.fillna(method='bfill')
# Out:
# <ipython-input-147-17433a7dd472>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_.fillna(method='bfill')
#      x
# 0  1.0
# 1  2.0
# 2  4.0
# 3  4.0

# %%
df_.interpolate()
# Out:
#      x
# 0  1.0
# 1  2.0
# 2  3.0
# 3  4.0

# %% [markdown]
# #### Deleting Rows and Columns With Missing Data

# %%
df_.dropna()
# Out:
#      x
# 0  1.0
# 1  2.0
# 3  4.0

# %% [markdown]
# #### Iterating Over a pandas DataFrame

# %%
for col_label, col in df.items():
    print(col_label, col, sep='\n', end='\n\n')
# Out:
# name
# 0    Xavier
# 1       Ann
# 2      Jana
# 3        Yi
# 4     Robin
# 5      Amal
# 6      Nori
# 7     Rimas
# Name: name, dtype: object
#
# city
# 0    Mexico City
# 1        Toronto
# 2         Prague
# 3       Shanghai
# 4     Manchester
# 5          Cairo
# 6          Osaka
# 7         Jeddah
# Name: city, dtype: object
#
# py-score
# 0    88.0
# 1    79.0
# 2    81.0
# 3    80.0
# 4    68.0
# 5    61.0
# 6    84.0
# 7    88.0
# Name: py-score, dtype: float64
#
# django-score
# 0    86.0
# 1    81.0
# 2    78.0
# 3    88.0
# 4    74.0
# 5    70.0
# 6    81.0
# 7    81.0
# Name: django-score, dtype: float64
#
# js-score
# 0    71.0
# 1    95.0
# 2    88.0
# 3    79.0
# 4    91.0
# 5    91.0
# 6    80.0
# 7    80.0
# Name: js-score, dtype: float64
#
# total
# 0    82.3
# 1    84.4
# 2    82.2
# 3    82.1
# 4    76.7
# 5    72.7
# 6    81.9
# 7    83.5
# Name: total, dtype: float64

# %%
for row_label, row in df.iterrows():
     print(row_label, row, sep='\n', end='\n\n')
# Out:
# 0
# name                 Xavier
# city            Mexico City
# py-score               88.0
# django-score           86.0
# js-score               71.0
# total                  82.3
# Name: 0, dtype: object
#
# 1
# name                Ann
# city            Toronto
# py-score           79.0
# django-score       81.0
# js-score           95.0
# total              84.4
# Name: 1, dtype: object
#
# 2
# name              Jana
# city            Prague
# py-score          81.0
# django-score      78.0
# js-score          88.0
# total             82.2
# Name: 2, dtype: object
#
# 3
# name                  Yi
# city            Shanghai
# py-score            80.0
# django-score        88.0
# js-score            79.0
# total               82.1
# Name: 3, dtype: object
#
# 4
# name                 Robin
# city            Manchester
# py-score              68.0
# django-score          74.0
# js-score              91.0
# total                 76.7
# Name: 4, dtype: object
#
# 5
# name             Amal
# city            Cairo
# py-score         61.0
# django-score     70.0
# js-score         91.0
# total            72.7
# Name: 5, dtype: object
#
# 6
# name             Nori
# city            Osaka
# py-score         84.0
# django-score     81.0
# js-score         80.0
# total            81.9
# Name: 6, dtype: object
#
# 7
# name             Rimas
# city            Jeddah
# py-score          88.0
# django-score      81.0
# js-score          80.0
# total             83.5
# Name: 7, dtype: object

# %%
for row in df.loc[:, ['name', 'city', 'total']].itertuples():
     print(row)
# Out:
# Pandas(Index=0, name='Xavier', city='Mexico City', total=82.3)
# Pandas(Index=1, name='Ann', city='Toronto', total=84.4)
# Pandas(Index=2, name='Jana', city='Prague', total=82.19999999999999)
# Pandas(Index=3, name='Yi', city='Shanghai', total=82.1)
# Pandas(Index=4, name='Robin', city='Manchester', total=76.7)
# Pandas(Index=5, name='Amal', city='Cairo', total=72.7)
# Pandas(Index=6, name='Nori', city='Osaka', total=81.9)
# Pandas(Index=7, name='Rimas', city='Jeddah', total=83.5)

# %% [markdown]
# #### Working With Time Series
# Creating DataFrames With Time-Series Labels

# %%
temp_c = [ 8.0,  7.1,  6.8,  6.4,  6.0,  5.4,  4.8,  5.0,
            9.1, 12.8, 15.3, 19.1, 21.2, 22.1, 22.4, 23.1,
           21.0, 17.9, 15.5, 14.4, 11.9, 11.0, 10.2,  9.1]

# %%
dt = pd.date_range(start='2019-10-27 00:00:00.0', periods=24,
                    freq='H')
dt
# Out:
# DatetimeIndex(['2019-10-27 00:00:00', '2019-10-27 01:00:00',
#                '2019-10-27 02:00:00', '2019-10-27 03:00:00',
#                '2019-10-27 04:00:00', '2019-10-27 05:00:00',
#                '2019-10-27 06:00:00', '2019-10-27 07:00:00',
#                '2019-10-27 08:00:00', '2019-10-27 09:00:00',
#                '2019-10-27 10:00:00', '2019-10-27 11:00:00',
#                '2019-10-27 12:00:00', '2019-10-27 13:00:00',
#                '2019-10-27 14:00:00', '2019-10-27 15:00:00',
#                '2019-10-27 16:00:00', '2019-10-27 17:00:00',
#                '2019-10-27 18:00:00', '2019-10-27 19:00:00',
#                '2019-10-27 20:00:00', '2019-10-27 21:00:00',
#                '2019-10-27 22:00:00', '2019-10-27 23:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
temp = pd.DataFrame(data={'temp_c': temp_c}, index=dt)
temp
# Out:
#                      temp_c
# 2019-10-27 00:00:00     8.0
# 2019-10-27 01:00:00     7.1
# 2019-10-27 02:00:00     6.8
# 2019-10-27 03:00:00     6.4
# 2019-10-27 04:00:00     6.0
# 2019-10-27 05:00:00     5.4
# 2019-10-27 06:00:00     4.8
# 2019-10-27 07:00:00     5.0
# 2019-10-27 08:00:00     9.1
# 2019-10-27 09:00:00    12.8
# 2019-10-27 10:00:00    15.3
# 2019-10-27 11:00:00    19.1
# 2019-10-27 12:00:00    21.2
# 2019-10-27 13:00:00    22.1
# 2019-10-27 14:00:00    22.4
# 2019-10-27 15:00:00    23.1
# 2019-10-27 16:00:00    21.0
# 2019-10-27 17:00:00    17.9
# 2019-10-27 18:00:00    15.5
# 2019-10-27 19:00:00    14.4
# 2019-10-27 20:00:00    11.9
# 2019-10-27 21:00:00    11.0
# 2019-10-27 22:00:00    10.2
# 2019-10-27 23:00:00     9.1

# %% [markdown]
# #### Indexing and Slicing

# %%
temp['2019-10-27 05':'2019-10-27 14']
# Out:
#                      temp_c
# 2019-10-27 05:00:00     5.4
# 2019-10-27 06:00:00     4.8
# 2019-10-27 07:00:00     5.0
# 2019-10-27 08:00:00     9.1
# 2019-10-27 09:00:00    12.8
# 2019-10-27 10:00:00    15.3
# 2019-10-27 11:00:00    19.1
# 2019-10-27 12:00:00    21.2
# 2019-10-27 13:00:00    22.1
# 2019-10-27 14:00:00    22.4

# %% [markdown]
# #### Resampling and Rolling

# %%
temp.resample(rule='6h').mean()
# Out:
#                         temp_c
# 2019-10-27 00:00:00   6.616667
# 2019-10-27 06:00:00  11.016667
# 2019-10-27 12:00:00  21.283333
# 2019-10-27 18:00:00  12.016667

# %%
temp.rolling(window=3).mean()
# Out:
#                         temp_c
# 2019-10-27 00:00:00        NaN
# 2019-10-27 01:00:00        NaN
# 2019-10-27 02:00:00   7.300000
# 2019-10-27 03:00:00   6.766667
# 2019-10-27 04:00:00   6.400000
# 2019-10-27 05:00:00   5.933333
# 2019-10-27 06:00:00   5.400000
# 2019-10-27 07:00:00   5.066667
# 2019-10-27 08:00:00   6.300000
# 2019-10-27 09:00:00   8.966667
# 2019-10-27 10:00:00  12.400000
# 2019-10-27 11:00:00  15.733333
# 2019-10-27 12:00:00  18.533333
# 2019-10-27 13:00:00  20.800000
# 2019-10-27 14:00:00  21.900000
# 2019-10-27 15:00:00  22.533333
# 2019-10-27 16:00:00  22.166667
# 2019-10-27 17:00:00  20.666667
# 2019-10-27 18:00:00  18.133333
# 2019-10-27 19:00:00  15.933333
# 2019-10-27 20:00:00  13.933333
# 2019-10-27 21:00:00  12.433333
# 2019-10-27 22:00:00  11.033333
# 2019-10-27 23:00:00  10.100000

# %% [markdown]
# #### Plotting With pandas DataFrames

# %%
import matplotlib.pyplot as plt

# %%
temp.plot()
plt.show()

# %%
temp.plot().get_figure().savefig('temperatures.png')

# %%
df.loc[:, ['py-score', 'total']].plot.hist(bins=5, alpha=0.4)
plt.show()

# %% [markdown]
# ## The End
